# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
import random
import time

# %%
## Loading data
sediment = pd.read_csv('D:\SCI논문\퇴적물측정망(231003)\Python code\sediment_read.csv', encoding='cp949')

# %%
sediment = sediment.dropna(axis=0).dropna(axis=1)

# %%
sediment
# Out:
#         region   spot  year  month  day   half    pollution  depth  WT    DO  \
# 0      Nakdong  거창위천2  2015      3   30  first  slightlybad    0.5  15   8.7
# 1         Geum   곡교천2  2015      3   31  first  slightlybad    1.0  16   6.3
# 2     Yeongsan     곡성  2015      3   26  first       normal    0.7  15  12.5
# 3      Nakdong    곤양천  2015      3   23  first  slightlybad    1.0  13  10.3
# 4     Yeongsan   광양서천  2015      3   30  first  slightlybad    0.7  16  11.1
# ...        ...    ...   ...    ...  ...    ...          ...    ...  ..   ...
# 3201   Nakdong   연초댐1  2022      6   15  first  slightlybad   13.0  23   9.6
# 3202   Nakdong   영주댐1  2022      6   17  first  slightlybad   21.0  22   8.5
# 3203   Nakdong   영주댐2  2022      6   17  first  slightlybad    9.0  23   9.8
# 3204   Nakdong   영주댐3  2022      6   17  first  slightlybad    9.0  24  15.6
# 3205  Yeongsan    평림댐  2022      6   10  first  slightlybad   16.0  22   9.4
#
#       ...    Pb     Zn     Cu     Cr    Ni    As    Cd     Hg     Al    Li
# 0     ...  19.9   55.0   11.5   21.6   3.2   1.5  0.10  0.091   9.35  14.6
# 1     ...  29.6  259.9  104.9   90.4  35.0   6.7  0.55  0.093  10.77  33.9
# 2     ...  28.9  127.5   24.7   32.9  14.5   7.9  0.24  0.048   7.70  77.5
# 3     ...  10.3   77.1   15.8  251.8  17.3   3.2  0.10  0.013   6.51  15.5
# 4     ...  44.1  237.7   45.1   45.7  20.6  10.0  0.58  0.041   9.36  34.3
# ...   ...   ...    ...    ...    ...   ...   ...   ...    ...    ...   ...
# 3201  ...  20.7  122.3   36.7   45.8  19.9   7.6  0.29  0.078   7.12  70.0
# 3202  ...  26.7  160.5   21.5   44.4  15.1   9.8  0.21  0.079   8.62  86.2
# 3203  ...  30.3  195.4   31.0   44.3  17.8  13.4  0.25  0.101   9.54  95.0
# 3204  ...  23.9  208.4   23.9   40.9  15.8   7.8  0.22  0.070   9.86  77.0
# 3205  ...  31.9  124.0   28.5   60.8  29.1  10.7  0.26  0.073   8.28  91.3
#
# [3205 rows x 32 columns]

# %%
## Divide train and test
sediment_train_x = sediment.loc[(sediment.year != 2021) & (sediment.year != 2022),:].iloc[:,range(7,32)]
sediment_train_y = sediment.loc[(sediment.year != 2021) & (sediment.year != 2022),:].iloc[:,6]
sediment_test_x = sediment.loc[(sediment.year == 2021) | (sediment.year == 2022),:].iloc[:,range(7,32)]
sediment_test_y = sediment.loc[(sediment.year == 2021) | (sediment.year == 2022),:].iloc[:,6]

Han = sediment.loc[sediment.region == "Han",:]
Han_train_x = Han.loc[(Han.year != 2021) & (Han.year != 2022),:].iloc[:,range(7,32)]
Han_train_y = Han.loc[(Han.year != 2021) & (Han.year != 2022),:].iloc[:,6]
Han_test_x = Han.loc[(Han.year == 2021) | (Han.year == 2022),:].iloc[:,range(7,32)]
Han_test_y = Han.loc[(Han.year == 2021) | (Han.year == 2022),:].iloc[:,6]

Nakdong = sediment.loc[sediment.region == "Nakdong",:]
Nakdong_train_x = Nakdong.loc[(Nakdong.year != 2021) & (Nakdong.year != 2022),:].iloc[:,range(7,32)]
Nakdong_train_y = Nakdong.loc[(Nakdong.year != 2021) & (Nakdong.year != 2022),:].iloc[:,6]
Nakdong_test_x = Nakdong.loc[(Nakdong.year == 2021) | (Nakdong.year == 2022),:].iloc[:,range(7,32)]
Nakdong_test_y = Nakdong.loc[(Nakdong.year == 2021) | (Nakdong.year == 2022),:].iloc[:,6]

Geum = sediment.loc[sediment.region == "Geum",:]
Geum_train_x = Geum.loc[(Geum.year != 2021) & (Geum.year != 2022),:].iloc[:,range(7,32)]
Geum_train_y = Geum.loc[(Geum.year != 2021) & (Geum.year != 2022),:].iloc[:,6]
Geum_test_x = Geum.loc[(Geum.year == 2021) | (Geum.year == 2022),:].iloc[:,range(7,32)]
Geum_test_y = Geum.loc[(Geum.year == 2021) | (Geum.year == 2022),:].iloc[:,6]

Yeongsan = sediment.loc[sediment.region == "Yeongsan",:]
Yeongsan_train_x = Yeongsan.loc[(Yeongsan.year != 2021) & (Yeongsan.year != 2022),:].iloc[:,range(7,32)]
Yeongsan_train_y = Yeongsan.loc[(Yeongsan.year != 2021) & (Yeongsan.year != 2022),:].iloc[:,6]
Yeongsan_test_x = Yeongsan.loc[(Yeongsan.year == 2021) | (Yeongsan.year == 2022),:].iloc[:,range(7,32)]
Yeongsan_test_y = Yeongsan.loc[(Yeongsan.year == 2021) | (Yeongsan.year == 2022),:].iloc[:,6]

# %%
### Data processing
## Label Encoder
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
sediment['encoded_pollution'] = encoder.fit_transform(sediment['pollution'])
sediment['encoded_pollution']
# Out:
# 0       2
# 1       2
# 2       1
# 3       2
# 4       2
#        ..
# 3201    2
# 3202    2
# 3203    2
# 3204    2
# 3205    2
# Name: encoded_pollution, Length: 3205, dtype: int32

# %%
encoder.inverse_transform(sediment['encoded_pollution'])
# Out:
# array(['slightlybad', 'slightlybad', 'normal', ..., 'slightlybad',
#        'slightlybad', 'slightlybad'], dtype=object)

# %%
sediment_train_x = sediment.loc[(sediment.year != 2021) & (sediment.year != 2022),:].iloc[:,range(7,32)]
sediment_train_y = sediment.loc[(sediment.year != 2021) & (sediment.year != 2022),:].iloc[:,6]
sediment_encoded_train_y = sediment.loc[(sediment.year != 2021) & (sediment.year != 2022),:].iloc[:,32]
sediment_test_x = sediment.loc[(sediment.year == 2021) | (sediment.year == 2022),:].iloc[:,range(7,32)]
sediment_test_y = sediment.loc[(sediment.year == 2021) | (sediment.year == 2022),:].iloc[:,6]
sediment_encoded_test_y = sediment.loc[(sediment.year == 2021) | (sediment.year == 2022),:].iloc[:,32]

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\hi\anaconda3\lib\site-packages (0.10.1)
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hi\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hi\anaconda3\lib\site-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hi\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hi\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hi\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Using cached imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.11.0

# %%
### Sampling for imbalanced data
from sklearn.datasets import make_classification
from collections import Counter

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from imblearn.under_sampling import RandomUnderSampler, EditedNearestNeighbours 
from imblearn.over_sampling import RandomOverSampler, SMOTE, BorderlineSMOTE, ADASYN
from imblearn.combine import SMOTEENN, SMOTETomek

# %%
# SMOTE
sm_sample = SMOTE(random_state=2345) 
sediment_train_x_sm, sediment_encoded_train_y_sm = sm_sample.fit_resample(sediment_train_x, sediment_encoded_train_y)

# %%
Counter(sediment_encoded_train_y)
# Out:
# Counter({2: 847, 1: 1630, 0: 107, 3: 105})

# %%
Counter(sediment_encoded_train_y_sm)
# Out:
# Counter({2: 1630, 1: 1630, 0: 1630, 3: 1630})

# %%
# ADASYN
ads_sample = ADASYN(random_state=2345) 
sediment_train_x_ads, sediment_encoded_train_y_ads = ads_sample.fit_resample(sediment_train_x, sediment_encoded_train_y)

# %%
Counter(sediment_encoded_train_y)
# Out:
# Counter({2: 847, 1: 1630, 0: 107, 3: 105})

# %%
Counter(sediment_encoded_train_y_ads)
# Out:
# Counter({2: 1566, 1: 1630, 0: 1643, 3: 1617})

# %%
# SMOTE-ENN
sme_sample = SMOTEENN(random_state=2345) 
sediment_train_x_sme, sediment_encoded_train_y_sme = sme_sample.fit_resample(sediment_train_x, sediment_encoded_train_y)

# %%
Counter(sediment_encoded_train_y)
# Out:
# Counter({2: 847, 1: 1630, 0: 107, 3: 105})

# %%
Counter(sediment_encoded_train_y_sme)
# Out:
# Counter({0: 1495, 1: 757, 2: 895, 3: 1546})

# %%
# SMOTE-Tomek
smt_sample = SMOTETomek(random_state=2345) 
sediment_train_x_smt, sediment_encoded_train_y_smt = smt_sample.fit_resample(sediment_train_x, sediment_encoded_train_y)

# %%
Counter(sediment_encoded_train_y)
# Out:
# Counter({2: 847, 1: 1630, 0: 107, 3: 105})

# %%
Counter(sediment_encoded_train_y_smt)
# Out:
# Counter({2: 1554, 1: 1554, 0: 1621, 3: 1621})

# %%
### Hyperparameter tuning reference
# KNN : https://www.kaggle.com/code/arunimsamudra/k-nn-with-hyperparameter-tuning
# GaussianNB : https://www.kaggle.com/code/akshaysharma001/naive-bayes-with-hyperpameter-tuning
# Bagging : https://www.kaggle.com/code/juanmah/tactic-03-hyperparameter-optimization-bagging
# Random Forest : https://www.kaggle.com/code/arjunprasadsarkhel/simple-random-forest-with-hyperparameter-tuning
# AdaBoost : https://www.kaggle.com/code/juanmah/tactic-03-hyperparameter-optimization-adaboost 
# XGBoost : https://www.kaggle.com/code/michalbrezk/xgboost-classifier-and-hyperparameter-tuning-85  
# SVM : https://www.kaggle.com/code/rajeevnair676/svm-hyperparameter-tuning

# %%
### K-Nearest Neighbor (KNN)

# %%
## KNN with SMOTE
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
from sklearn import metrics
# calculating the accuracy of models with different values of k
mean_acc = np.zeros(20)
for i in range(1,21):
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors = i).fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
    yhat= knn.predict(np.array(sediment_test_x))
    mean_acc[i-1] = metrics.accuracy_score(sediment_encoded_test_y, yhat)

mean_acc
# Out:
# array([0.62984496, 0.65310078, 0.60852713, 0.64341085, 0.61046512,
#        0.61627907, 0.6124031 , 0.60852713, 0.60077519, 0.60271318,
#        0.58527132, 0.59689922, 0.57751938, 0.59108527, 0.58527132,
#        0.60077519, 0.59689922, 0.58914729, 0.56782946, 0.57364341])

# %%
loc = np.arange(1,21,step=1.0)
plt.figure(figsize = (10, 6))
plt.plot(range(1,21), mean_acc)
plt.xticks(loc)
plt.xlabel('Number of Neighbors ')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
grid_params = { 'n_neighbors' : range(1,21),
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 2, cv = 5, n_jobs = -1)

# %%
# fit the model on our train set
g_res = gs.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits

# %%
# find the best score
g_res.best_score_
# Out:
# 0.8897239263803682

# %%
# get the hyperparameters with the best score
g_res.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
# use the best hyperparameters
knn = KNeighborsClassifier(n_neighbors = 1, weights = 'uniform', algorithm = 'brute', metric = 'manhattan')
knn.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# KNeighborsClassifier(algorithm='brute', metric='manhattan', n_neighbors=1)

# %%
# get a prediction
y_hat = knn.predict(np.array(sediment_train_x_sm))
y_knn = knn.predict(np.array(sediment_test_x))
print('Training set accuracy: ', metrics.accuracy_score(sediment_encoded_train_y_sm, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(sediment_encoded_test_y, y_knn))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  0.6976744186046512

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_knn))
# Out:
# [[ 14   0   7   3]
#  [  3 233  72   3]
#  [ 12  47  99   2]
#  [  2   3   2  14]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.58      0.51        24
#            1       0.82      0.75      0.78       311
#            2       0.55      0.62      0.58       160
#            3       0.64      0.67      0.65        21
#
#     accuracy                           0.70       516
#    macro avg       0.62      0.65      0.63       516
# weighted avg       0.71      0.70      0.70       516

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(knn, np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm), cv=5)
print('Model accuracy: ',np.mean(scores))
# Out:
# Model accuracy:  0.8897239263803682

# %%
## KNN with ADASYN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
from sklearn import metrics
# calculating the accuracy of models with different values of k
mean_acc = np.zeros(20)
for i in range(1,21):
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors = i).fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
    yhat= knn.predict(np.array(sediment_test_x))
    mean_acc[i-1] = metrics.accuracy_score(sediment_encoded_test_y, yhat)

mean_acc
# Out:
# array([0.63178295, 0.64341085, 0.61627907, 0.62209302, 0.59108527,
#        0.61046512, 0.58139535, 0.59689922, 0.57364341, 0.58914729,
#        0.57945736, 0.59302326, 0.56976744, 0.59302326, 0.57170543,
#        0.58139535, 0.55620155, 0.56976744, 0.55813953, 0.5620155 ])

# %%
loc = np.arange(1,21,step=1.0)
plt.figure(figsize = (10, 6))
plt.plot(range(1,21), mean_acc)
plt.xticks(loc)
plt.xlabel('Number of Neighbors ')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
grid_params = { 'n_neighbors' : range(1,21),
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 2, cv = 5, n_jobs = -1)

# %%
# fit the model on our train set
g_res = gs.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits

# %%
# find the best score
g_res.best_score_
# Out:
# 0.8585858755422754

# %%
# get the hyperparameters with the best score
g_res.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
# use the best hyperparameters
knn = KNeighborsClassifier(n_neighbors = 1, weights = 'uniform', algorithm = 'brute', metric = 'manhattan')
knn.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# KNeighborsClassifier(algorithm='brute', metric='manhattan', n_neighbors=1)

# %%
# get a prediction
y_hat = knn.predict(np.array(sediment_train_x_ads))
y_knn = knn.predict(np.array(sediment_test_x))
print('Training set accuracy: ', metrics.accuracy_score(sediment_encoded_train_y_ads, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(sediment_encoded_test_y, y_knn))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  0.689922480620155

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_knn))
# Out:
# [[ 14   1   6   3]
#  [  2 231  74   4]
#  [ 11  48  97   4]
#  [  2   3   2  14]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.58      0.53        24
#            1       0.82      0.74      0.78       311
#            2       0.54      0.61      0.57       160
#            3       0.56      0.67      0.61        21
#
#     accuracy                           0.69       516
#    macro avg       0.60      0.65      0.62       516
# weighted avg       0.71      0.69      0.70       516

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(knn, np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads), cv=5)
print('Model accuracy: ',np.mean(scores))
# Out:
# Model accuracy:  0.8585858755422754

# %%
## KNN with SMOTE-ENN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
from sklearn import metrics
# calculating the accuracy of models with different values of k
mean_acc = np.zeros(20)
for i in range(1,21):
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors = i).fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
    yhat= knn.predict(np.array(sediment_test_x))
    mean_acc[i-1] = metrics.accuracy_score(sediment_encoded_test_y, yhat)

mean_acc
# Out:
# array([0.59302326, 0.58914729, 0.54457364, 0.55620155, 0.54651163,
#        0.54651163, 0.53682171, 0.53682171, 0.5251938 , 0.52713178,
#        0.51162791, 0.52131783, 0.50581395, 0.50968992, 0.5       ,
#        0.50775194, 0.49612403, 0.5       , 0.49806202, 0.5       ])

# %%
loc = np.arange(1,21,step=1.0)
plt.figure(figsize = (10, 6))
plt.plot(range(1,21), mean_acc)
plt.xticks(loc)
plt.xlabel('Number of Neighbors ')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
grid_params = { 'n_neighbors' : range(1,21),
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 2, cv = 5, n_jobs = -1)

# %%
# fit the model on our train set
g_res = gs.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits

# %%
# find the best score
g_res.best_score_
# Out:
# 0.987214316368863

# %%
# get the hyperparameters with the best score
g_res.best_params_
# Out:
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
# use the best hyperparameters
knn = KNeighborsClassifier(n_neighbors = 1, weights = 'uniform', algorithm = 'brute', metric = 'minkowski')
knn.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# KNeighborsClassifier(algorithm='brute', n_neighbors=1)

# %%
# get a prediction
y_hat = knn.predict(np.array(sediment_train_x_sme))
y_knn = knn.predict(np.array(sediment_test_x))
print('Training set accuracy: ', metrics.accuracy_score(sediment_encoded_train_y_sme, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(sediment_encoded_test_y, y_knn))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  0.5930232558139535

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_knn))
# Out:
# [[ 10   3   6   5]
#  [ 12 195  97   7]
#  [ 18  45  88   9]
#  [  6   0   2  13]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.42      0.29        24
#            1       0.80      0.63      0.70       311
#            2       0.46      0.55      0.50       160
#            3       0.38      0.62      0.47        21
#
#     accuracy                           0.59       516
#    macro avg       0.46      0.55      0.49       516
# weighted avg       0.65      0.59      0.61       516

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(knn, np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme), cv=5)
print('Model accuracy: ',np.mean(scores))
# Out:
# Model accuracy:  0.987214316368863

# %%
## KNN with SMOTE-Tomek
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
from sklearn import metrics
# calculating the accuracy of models with different values of k
mean_acc = np.zeros(20)
for i in range(1,21):
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors = i).fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
    yhat= knn.predict(np.array(sediment_test_x))
    mean_acc[i-1] = metrics.accuracy_score(sediment_encoded_test_y, yhat)

mean_acc
# Out:
# array([0.62984496, 0.65116279, 0.60852713, 0.63953488, 0.61434109,
#        0.62015504, 0.61046512, 0.60658915, 0.59689922, 0.59496124,
#        0.58333333, 0.5872093 , 0.58139535, 0.58527132, 0.57945736,
#        0.58527132, 0.5755814 , 0.57170543, 0.5620155 , 0.56589147])

# %%
loc = np.arange(1,21,step=1.0)
plt.figure(figsize = (10, 6))
plt.plot(range(1,21), mean_acc)
plt.xticks(loc)
plt.xlabel('Number of Neighbors ')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
grid_params = { 'n_neighbors' : range(1,21),
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 2, cv = 5, n_jobs = -1)

# %%
# fit the model on our train set
g_res = gs.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits

# %%
# find the best score
g_res.best_score_
# Out:
# 0.9088188976377953

# %%
# get the hyperparameters with the best score
g_res.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
# use the best hyperparameters
knn = KNeighborsClassifier(n_neighbors = 1, weights = 'uniform', algorithm = 'brute', metric = 'manhattan')
knn.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# KNeighborsClassifier(algorithm='brute', metric='manhattan', n_neighbors=1)

# %%
# get a prediction
y_hat = knn.predict(np.array(sediment_train_x_smt))
y_knn = knn.predict(np.array(sediment_test_x))
print('Training set accuracy: ', metrics.accuracy_score(sediment_encoded_train_y_smt, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(sediment_encoded_test_y, y_knn))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  0.689922480620155

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_knn))
# Out:
# [[ 14   0   7   3]
#  [  3 231  74   3]
#  [ 12  49  97   2]
#  [  2   3   2  14]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.58      0.51        24
#            1       0.82      0.74      0.78       311
#            2       0.54      0.61      0.57       160
#            3       0.64      0.67      0.65        21
#
#     accuracy                           0.69       516
#    macro avg       0.61      0.65      0.63       516
# weighted avg       0.71      0.69      0.70       516

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(knn, np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt), cv=5)
print('Model accuracy: ',np.mean(scores))
# Out:
# Model accuracy:  0.9088188976377953

# %%
### Gaussian Naive Bayes (GaussianNB)
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
## GaussianNB with SMOTE
model = GaussianNB()
model
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import PowerTransformer

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=2, 
                     scoring='accuracy')

# Data_transformed = PowerTransformer().fit_transform(np.array(sediment_train_x_sm))

gs_NB.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# ...
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=999),
#              estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=2)

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 1e-09}

# %%
gs_NB.best_score_
# Out:
# 0.7520961145194274

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']
results_NB
# Out:
#     var_smoothing  test_score
# 0    1.000000e+00    0.263292
# 1    8.111308e-01    0.264877
# 2    6.579332e-01    0.267536
# 3    5.336699e-01    0.270501
# 4    4.328761e-01    0.274233
# ..            ...         ...
# 95   2.310130e-09    0.743558
# 96   1.873817e-09    0.745654
# 97   1.519911e-09    0.747495
# 98   1.232847e-09    0.749387
# 99   1.000000e-09    0.752096
#
# [100 rows x 2 columns]

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("GaussianNB Performance Comparison")
plt.show()

# %%
gnb = GaussianNB(var_smoothing = 1e-09)
gnb.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# GaussianNB()

# %%
# predict the target on the test dataset
# Data_transformed_test = PowerTransformer().fit_transform(np.array(sediment_test_x))
y_NB = gnb.predict(np.array(sediment_test_x))

# Accuracy Score on test dataset
accuracy_test = accuracy_score(sediment_encoded_test_y, y_NB)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.7306201550387597

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_NB))
# Out:
# [[ 16   0   3   5]
#  [  0 242  66   3]
#  [ 10  35 107   8]
#  [  4   4   1  12]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.67      0.59        24
#            1       0.86      0.78      0.82       311
#            2       0.60      0.67      0.64       160
#            3       0.43      0.57      0.49        21
#
#     accuracy                           0.73       516
#    macro avg       0.61      0.67      0.63       516
# weighted avg       0.75      0.73      0.74       516

# %%
## GaussianNB with ADASYN
model = GaussianNB()
model
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import PowerTransformer

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=2, 
                     scoring='accuracy')

# Data_transformed = PowerTransformer().fit_transform(np.array(sediment_train_x_ads))

gs_NB.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# ...
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=999),
#              estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=2)

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 1e-09}

# %%
gs_NB.best_score_
# Out:
# 0.742512624112795

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']
results_NB
# Out:
#     var_smoothing  test_score
# 0    1.000000e+00    0.264819
# 1    8.111308e-01    0.264767
# 2    6.579332e-01    0.264767
# 3    5.336699e-01    0.264612
# 4    4.328761e-01    0.265283
# ..            ...         ...
# 95   2.310130e-09    0.731154
# 96   1.873817e-09    0.733735
# 97   1.519911e-09    0.736575
# 98   1.232847e-09    0.739983
# 99   1.000000e-09    0.742513
#
# [100 rows x 2 columns]

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("GaussianNB Performance Comparison")
plt.show()

# %%
gnb = GaussianNB(var_smoothing = 1e-09)
gnb.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# GaussianNB()

# %%
# predict the target on the test dataset
# Data_transformed_test = PowerTransformer().fit_transform(np.array(sediment_test_x))
y_NB = gnb.predict(np.array(sediment_test_x))

# Accuracy Score on test dataset
accuracy_test = accuracy_score(sediment_encoded_test_y, y_NB)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.7693798449612403

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_NB))
# Out:
# [[ 18   0   3   3]
#  [  1 259  47   4]
#  [ 12  32 109   7]
#  [  5   3   2  11]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60        24
#            1       0.88      0.83      0.86       311
#            2       0.68      0.68      0.68       160
#            3       0.44      0.52      0.48        21
#
#     accuracy                           0.77       516
#    macro avg       0.62      0.70      0.65       516
# weighted avg       0.78      0.77      0.77       516

# %%
## Gaussian NB with SMOTE-ENN
model = GaussianNB()
model
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import PowerTransformer

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=2, 
                     scoring='accuracy')

# Data_transformed = PowerTransformer().fit_transform(np.array(sediment_train_x_sme))

gs_NB.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# ...
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=999),
#              estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=2)

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 8.111308307896873e-08}

# %%
gs_NB.best_score_
# Out:
# 0.7792460185002267

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']
results_NB
# Out:
#     var_smoothing  test_score
# 0    1.000000e+00    0.427940
# 1    8.111308e-01    0.424031
# 2    6.579332e-01    0.421260
# 3    5.336699e-01    0.416217
# 4    4.328761e-01    0.410038
# ..            ...         ...
# 95   2.310130e-09    0.772853
# 96   1.873817e-09    0.774842
# 97   1.519911e-09    0.775623
# 98   1.232847e-09    0.775978
# 99   1.000000e-09    0.776972
#
# [100 rows x 2 columns]

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("GaussianNB Performance Comparison")
plt.show()

# %%
gnb = GaussianNB(var_smoothing = 8.111308307896873e-08)
gnb.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# GaussianNB(var_smoothing=8.111308307896873e-08)

# %%
# predict the target on the test dataset
# Data_transformed_test = PowerTransformer().fit_transform(np.array(sediment_test_x))
y_NB = gnb.predict(np.array(sediment_test_x))

# Accuracy Score on test dataset
accuracy_test = accuracy_score(sediment_encoded_test_y, y_NB)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.6608527131782945

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_NB))
# Out:
# [[ 16   0   5   3]
#  [  4 199 100   8]
#  [ 20  25 108   7]
#  [  2   1   0  18]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.67      0.48        24
#            1       0.88      0.64      0.74       311
#            2       0.51      0.68      0.58       160
#            3       0.50      0.86      0.63        21
#
#     accuracy                           0.66       516
#    macro avg       0.57      0.71      0.61       516
# weighted avg       0.73      0.66      0.68       516

# %%
## GaussianNB with SMOTE-Tomek
model = GaussianNB()
model
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import PowerTransformer

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=2, 
                     scoring='accuracy')

# Data_transformed = PowerTransformer().fit_transform(np.array(sediment_train_x_smt))

gs_NB.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ..................................var_smoothing=1.0; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ...................var_smoothing=0.8111308307896871; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.657933224657568; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ....................var_smoothing=0.533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ..................var_smoothing=0.43287612810830584; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.3511191734215131; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ...................var_smoothing=0.2848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ..................var_smoothing=0.23101297000831597; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ...................var_smoothing=0.1873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.15199110829529336; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................var_smoothing=0.12328467394420659; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................................var_smoothing=0.1; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ..................var_smoothing=0.08111308307896872; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0657933224657568; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ...................var_smoothing=0.0533669923120631; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.04328761281083057; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.03511191734215131; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02848035868435802; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.02310129700083159; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01873817422860384; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END ..................var_smoothing=0.01519911082952933; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................var_smoothing=0.012328467394420659; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................................var_smoothing=0.01; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.008111308307896872; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.006579332246575682; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.005336699231206307; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.004328761281083057; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.003511191734215131; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END .................var_smoothing=0.002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END ................var_smoothing=0.0023101297000831605; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END .................var_smoothing=0.001873817422860383; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0015199110829529332; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................var_smoothing=0.0012328467394420659; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................................var_smoothing=0.001; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0008111308307896872; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0006579332246575676; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0005336699231206307; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0004328761281083057; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0003511191734215131; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# [CV] END ................var_smoothing=0.0002848035868435802; total time=   0.0s
# ...
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................var_smoothing=1.232846739442066e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=8.111308307896856e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=6.579332246575682e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=5.336699231206302e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ................var_smoothing=4.328761281083061e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ...............var_smoothing=3.5111917342151273e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.848035868435805e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=2.310129700083158e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.873817422860387e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ................var_smoothing=1.519911082952933e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ...............var_smoothing=1.2328467394420635e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# [CV] END ................................var_smoothing=1e-09; total time=   0.0s
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=999),
#              estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=2)

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 1e-09}

# %%
gs_NB.best_score_
# Out:
# 0.7516535433070868

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']
results_NB
# Out:
#     var_smoothing  test_score
# 0    1.000000e+00    0.261627
# 1    8.111308e-01    0.262835
# 2    6.579332e-01    0.265774
# 3    5.336699e-01    0.268924
# 4    4.328761e-01    0.272073
# ..            ...         ...
# 95   2.310130e-09    0.743150
# 96   1.873817e-09    0.745827
# 97   1.519911e-09    0.747034
# 98   1.232847e-09    0.748976
# 99   1.000000e-09    0.751654
#
# [100 rows x 2 columns]

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("GaussianNB Performance Comparison")
plt.show()

# %%
gnb = GaussianNB(var_smoothing = 1e-09)
gnb.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# GaussianNB()

# %%
# predict the target on the test dataset
# Data_transformed_test = PowerTransformer().fit_transform(np.array(sediment_test_x))
y_NB = gnb.predict(np.array(sediment_test_x))

# Accuracy Score on test dataset
accuracy_test = accuracy_score(sediment_encoded_test_y, y_NB)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.7306201550387597

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_NB))
# Out:
# [[ 16   0   3   5]
#  [  0 240  68   3]
#  [  9  35 108   8]
#  [  4   4   0  13]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60        24
#            1       0.86      0.77      0.81       311
#            2       0.60      0.68      0.64       160
#            3       0.45      0.62      0.52        21
#
#     accuracy                           0.73       516
#    macro avg       0.62      0.68      0.64       516
# weighted avg       0.75      0.73      0.74       516

# %%
### Bagging
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# from lwoku import RANDOM_STATE, N_JOBS, VERBOSE, get_prediction
# from grid_search_utils import plot_grid_search, table_grid_search

import pickle

# %%
## Bagging with SMOTE
bg_clf = BaggingClassifier()
bg_clf
# Out:
# BaggingClassifier()

# %%
parameters = {
    'n_estimators': [200, 500],
    'max_features': [0.90, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}
clf = GridSearchCV(bg_clf, parameters, cv = 3, verbose = 2, n_jobs = -1)
clf.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# plot_grid_search(clf)
# table_grid_search(clf)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=BaggingClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.9, 1.0],
#                          'n_estimators': [200, 500]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# BaggingClassifier(max_features=0.9, n_estimators=200)

# %%
print ('Random grid: ', parameters, '\n')
# print the best parameters
print ('Best Parameters: ', clf.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': [0.9, 1.0], 'bootstrap': [True, False], 'bootstrap_features': [True, False]}
#
# Best Parameters:  {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.9, 'n_estimators': 200}

# %%
randmb = BaggingClassifier(n_estimators = 200, max_features = 0.9, bootstrap = True, bootstrap_features = False) 
randmb.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# BaggingClassifier(max_features=0.9, n_estimators=200)

# %%
y_bag = randmb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_bag))
# Out:
# [[ 17   0   5   2]
#  [  0 290  20   1]
#  [  3   8 145   4]
#  [  0   0   1  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77        24
#            1       0.97      0.93      0.95       311
#            2       0.85      0.91      0.88       160
#            3       0.74      0.95      0.83        21
#
#     accuracy                           0.91       516
#    macro avg       0.85      0.87      0.86       516
# weighted avg       0.92      0.91      0.92       516

# %%
## Bagging with ADASYN
bg_clf = BaggingClassifier()
bg_clf
# Out:
# BaggingClassifier()

# %%
parameters = {
    'n_estimators': [200, 500],
    'max_features': [0.90, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}
clf = GridSearchCV(bg_clf, parameters, cv = 3, verbose = 2, n_jobs = -1)
clf.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# plot_grid_search(clf)
# table_grid_search(clf)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=BaggingClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.9, 1.0],
#                          'n_estimators': [200, 500]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# BaggingClassifier(bootstrap_features=True, n_estimators=500)

# %%
print ('Random grid: ', parameters, '\n')
# print the best parameters
print ('Best Parameters: ', clf.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': [0.9, 1.0], 'bootstrap': [True, False], 'bootstrap_features': [True, False]}
#
# Best Parameters:  {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'n_estimators': 500}

# %%
randmb = BaggingClassifier(n_estimators = 500, max_features = 1.0, bootstrap = True, bootstrap_features = True) 
randmb.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# BaggingClassifier(bootstrap_features=True, n_estimators=500)

# %%
y_bag = randmb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_bag))
# Out:
# [[ 17   0   4   3]
#  [  0 288  22   1]
#  [  2  15 140   3]
#  [  0   0   0  21]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79        24
#            1       0.95      0.93      0.94       311
#            2       0.84      0.88      0.86       160
#            3       0.75      1.00      0.86        21
#
#     accuracy                           0.90       516
#    macro avg       0.86      0.88      0.86       516
# weighted avg       0.91      0.90      0.90       516

# %%
## Bagging with SMOTE-ENN
bg_clf = BaggingClassifier()
bg_clf
# Out:
# BaggingClassifier()

# %%
parameters = {
    'n_estimators': [200, 500],
    'max_features': [0.90, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}
clf = GridSearchCV(bg_clf, parameters, cv = 3, verbose = 2, n_jobs = -1)
clf.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# plot_grid_search(clf)
# table_grid_search(clf)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=BaggingClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.9, 1.0],
#                          'n_estimators': [200, 500]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# BaggingClassifier(bootstrap=False, bootstrap_features=True, max_features=0.9,
#                   n_estimators=200)

# %%
print ('Random grid: ', parameters, '\n')
# print the best parameters
print ('Best Parameters: ', clf.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': [0.9, 1.0], 'bootstrap': [True, False], 'bootstrap_features': [True, False]}
#
# Best Parameters:  {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.9, 'n_estimators': 200}

# %%
randmb = BaggingClassifier(n_estimators = 200, max_features = 0.9, bootstrap = False, bootstrap_features = True) 
randmb.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# BaggingClassifier(bootstrap=False, bootstrap_features=True, max_features=0.9,
#                   n_estimators=200)

# %%
y_bag = randmb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_bag))
# Out:
# [[ 18   0   5   1]
#  [  0 256  49   6]
#  [  6  21 128   5]
#  [  0   1   0  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        24
#            1       0.92      0.82      0.87       311
#            2       0.70      0.80      0.75       160
#            3       0.62      0.95      0.75        21
#
#     accuracy                           0.82       516
#    macro avg       0.75      0.83      0.78       516
# weighted avg       0.83      0.82      0.82       516

# %%
##Bagging with SMOTE-Tomek
bg_clf = BaggingClassifier()
bg_clf
# Out:
# BaggingClassifier()

# %%
parameters = {
    'n_estimators': [200, 500],
    'max_features': [0.90, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}
clf = GridSearchCV(bg_clf, parameters, cv = 3, verbose = 2, n_jobs = -1)
clf.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# plot_grid_search(clf)
# table_grid_search(clf)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=BaggingClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.9, 1.0],
#                          'n_estimators': [200, 500]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# BaggingClassifier(max_features=0.9, n_estimators=200)

# %%
print ('Random grid: ', parameters, '\n')
# print the best parameters
print ('Best Parameters: ', clf.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': [0.9, 1.0], 'bootstrap': [True, False], 'bootstrap_features': [True, False]}
#
# Best Parameters:  {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.9, 'n_estimators': 200}

# %%
randmb = BaggingClassifier(n_estimators = 200, max_features = 0.9, bootstrap = True, bootstrap_features = False) 
randmb.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# BaggingClassifier(max_features=0.9, n_estimators=200)

# %%
y_bag = randmb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_bag))
# Out:
# [[ 18   0   5   1]
#  [  0 290  20   1]
#  [  3  13 140   4]
#  [  0   0   0  21]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        24
#            1       0.96      0.93      0.94       311
#            2       0.85      0.88      0.86       160
#            3       0.78      1.00      0.88        21
#
#     accuracy                           0.91       516
#    macro avg       0.86      0.89      0.87       516
# weighted avg       0.91      0.91      0.91       516

# %%
### Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
## Random Forest with SMOTE
rf = RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
n_estimators = [200,500] # number of trees in the random forest
max_features = ['auto', 'sqrt'] # number of features in consideration at every split
max_depth = [int(x) for x in np.linspace(10, 100, num = 5)] # maximum number of levels allowed in each decision tree
min_samples_split = [2, 10] # minimum sample number to split a node
min_samples_leaf = [1, 4] # minimum sample number that can be stored in a leaf node
bootstrap = [True, False] # method used to sample data points

random_grid = {'n_estimators': n_estimators,
'max_features': max_features,
'max_depth': max_depth,
'min_samples_split': min_samples_split,
'min_samples_leaf': min_samples_leaf,
'bootstrap': bootstrap}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,
               n_iter = 100, cv = 3, verbose=2, random_state=35, n_jobs = -1)

# %%
rf_random.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 156 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 156 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.92038967        nan        nan        nan 0.9133345
#  0.9202362         nan 0.90842662        nan 0.91195427 0.92345727
#         nan 0.9187025         nan        nan        nan 0.92315026
#  0.91134061        nan 0.92023627        nan 0.91946949 0.91946956
#  0.91272077        nan 0.91410085 0.91732199 0.91486819        nan
#  0.92345734 0.92391746 0.90765977        nan        nan        nan
#  0.92192343        nan 0.91762872 0.91149387 0.92422426        nan
#         nan 0.9134879  0.9202362  0.90673952        nan        nan
#  0.91364144 0.91870229        nan        nan 0.91640182 0.91655515
#         nan 0.92315047        nan 0.9199294         nan        nan
#         nan 0.91302735        nan 0.90551241 0.91808863 0.91348776
#  0.92284354        nan 0.91732214 0.91701534        nan        nan
#         nan        nan 0.91885604 0.91425439        nan 0.91962282
#         nan        nan        nan        nan        nan        nan
#         nan 0.9199294  0.90950033        nan        nan        nan
#  0.91072709        nan        nan        nan 0.91256758        nan
#         nan        nan 0.92023599 0.91440814]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 32, 55, 77, 100],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 4],
#                                         'min_samples_split': [2, 10],
#                                         'n_estimators': [200, 500]},
#                    random_state=35, verbose=2)

# %%
print ('Random grid: ', random_grid, '\n')
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 32, 55, 77, 100], 'min_samples_split': [2, 10], 'min_samples_leaf': [1, 4], 'bootstrap': [True, False]}
#
# Best Parameters:  {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 77, 'bootstrap': False}

# %%
randmf = RandomForestClassifier(n_estimators = 200, min_samples_split = 2, min_samples_leaf = 1, 
                                max_features = 'sqrt', max_depth = 77, bootstrap = False) 
randmf.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=77, n_estimators=200)

# %%
y_rf = randmf.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_rf))
# Out:
# [[ 18   0   5   1]
#  [  0 294  16   1]
#  [  0  20 139   1]
#  [  0   1   0  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86        24
#            1       0.93      0.95      0.94       311
#            2       0.87      0.87      0.87       160
#            3       0.87      0.95      0.91        21
#
#     accuracy                           0.91       516
#    macro avg       0.92      0.88      0.89       516
# weighted avg       0.91      0.91      0.91       516

# %%
## Random Forest with ADASYN
rf = RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
n_estimators = [200,500] # number of trees in the random forest
max_features = ['auto', 'sqrt'] # number of features in consideration at every split
max_depth = [int(x) for x in np.linspace(10, 100, num = 5)] # maximum number of levels allowed in each decision tree
min_samples_split = [2, 10] # minimum sample number to split a node
min_samples_leaf = [1, 4] # minimum sample number that can be stored in a leaf node
bootstrap = [True, False] # method used to sample data points

random_grid = {'n_estimators': n_estimators,
'max_features': max_features,
'max_depth': max_depth,
'min_samples_split': min_samples_split,
'min_samples_leaf': min_samples_leaf,
'bootstrap': bootstrap}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,
               n_iter = 100, cv = 3, verbose=2, random_state=35, n_jobs = -1)

# %%
rf_random.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 156 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 156 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.89095415        nan        nan        nan 0.89420694
#  0.89296778        nan 0.88289963        nan 0.8895601  0.90272615
#         nan 0.89219331        nan        nan        nan 0.90303594
#  0.88537794        nan 0.8923482         nan 0.8954461  0.89668525
#  0.88181537        nan 0.88104089 0.8925031  0.88057621        nan
#  0.90473978 0.90288104 0.87329616        nan        nan        nan
#  0.90179678        nan 0.89916357 0.88258984 0.90381041        nan
#         nan 0.87685874 0.89498141 0.87623916        nan        nan
#  0.89374226 0.89575589        nan        nan 0.89110905 0.88986989
#         nan 0.90319083        nan 0.89296778        nan        nan
#         nan 0.87964684        nan 0.87252169 0.89312268 0.88026642
#  0.8982342         nan 0.89002478 0.88986989        nan        nan
#         nan        nan 0.89482652 0.88104089        nan 0.88847584
#         nan        nan        nan        nan        nan        nan
#         nan 0.89699504 0.87856258        nan        nan        nan
#  0.88150558        nan        nan        nan 0.88197026        nan
#         nan        nan 0.89312268 0.87902726]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 32, 55, 77, 100],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 4],
#                                         'min_samples_split': [2, 10],
#                                         'n_estimators': [200, 500]},
#                    random_state=35, verbose=2)

# %%
print ('Random grid: ', random_grid, '\n')
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 32, 55, 77, 100], 'min_samples_split': [2, 10], 'min_samples_leaf': [1, 4], 'bootstrap': [True, False]}
#
# Best Parameters:  {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100, 'bootstrap': False}

# %%
randmf = RandomForestClassifier(n_estimators = 500, min_samples_split = 2, min_samples_leaf = 1, 
                                max_features = 'sqrt', max_depth = 100, bootstrap = False) 
randmf.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=100, n_estimators=500)

# %%
y_rf = randmf.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_rf))
# Out:
# [[ 16   0   7   1]
#  [  0 294  16   1]
#  [  2  17 139   2]
#  [  0   2   0  19]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        24
#            1       0.94      0.95      0.94       311
#            2       0.86      0.87      0.86       160
#            3       0.83      0.90      0.86        21
#
#     accuracy                           0.91       516
#    macro avg       0.88      0.85      0.86       516
# weighted avg       0.91      0.91      0.91       516

# %%
## Random Forest with SMOTE-ENN
rf = RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
n_estimators = [200,500] # number of trees in the random forest
max_features = ['auto', 'sqrt'] # number of features in consideration at every split
max_depth = [int(x) for x in np.linspace(10, 100, num = 5)] # maximum number of levels allowed in each decision tree
min_samples_split = [2, 10] # minimum sample number to split a node
min_samples_leaf = [1, 4] # minimum sample number that can be stored in a leaf node
bootstrap = [True, False] # method used to sample data points

random_grid = {'n_estimators': n_estimators,
'max_features': max_features,
'max_depth': max_depth,
'min_samples_split': min_samples_split,
'min_samples_leaf': min_samples_leaf,
'bootstrap': bootstrap}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,
               n_iter = 100, cv = 3, verbose=2, random_state=35, n_jobs = -1)

# %%
rf_random.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 156 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 43 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 113 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.95993588        nan        nan        nan 0.95524773
#  0.958018          nan 0.95162536        nan 0.95205176 0.96057473
#         nan 0.95844398        nan        nan        nan 0.960575
#  0.95183876        nan 0.95887038        nan 0.95823058 0.95929636
#  0.955461          nan 0.9541825  0.95567413 0.95290386        nan
#  0.96078772 0.96164078 0.94821598        nan        nan        nan
#  0.96014915        nan 0.95759215 0.95439563 0.96227921        nan
#         nan 0.95567399 0.958018   0.94715102        nan        nan
#  0.95482175 0.95759188        nan        nan 0.95610011 0.9565261
#         nan 0.96036173        nan 0.95737888        nan        nan
#         nan 0.95418209        nan 0.94736333 0.95631283 0.95482188
#  0.95865711        nan 0.955461   0.95695249        nan        nan
#         nan        nan 0.95759174 0.95375638        nan 0.95929663
#         nan        nan        nan        nan        nan        nan
#         nan 0.95823113 0.95013332        nan        nan        nan
#  0.95311726        nan        nan        nan 0.95588712        nan
#         nan        nan 0.95887065 0.9550346 ]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 32, 55, 77, 100],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 4],
#                                         'min_samples_split': [2, 10],
#                                         'n_estimators': [200, 500]},
#                    random_state=35, verbose=2)

# %%
print ('Random grid: ', random_grid, '\n')
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 32, 55, 77, 100], 'min_samples_split': [2, 10], 'min_samples_leaf': [1, 4], 'bootstrap': [True, False]}
#
# Best Parameters:  {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 77, 'bootstrap': False}

# %%
randmf = RandomForestClassifier(n_estimators = 200, min_samples_split = 2, min_samples_leaf = 1, 
                                max_features = 'sqrt', max_depth = 77, bootstrap = False) 
randmf.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=77, n_estimators=200)

# %%
y_rf = randmf.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_rf))
# Out:
# [[ 17   0   6   1]
#  [  0 258  47   6]
#  [  4  27 125   4]
#  [  0   1   0  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.76        24
#            1       0.90      0.83      0.86       311
#            2       0.70      0.78      0.74       160
#            3       0.65      0.95      0.77        21
#
#     accuracy                           0.81       516
#    macro avg       0.76      0.82      0.78       516
# weighted avg       0.83      0.81      0.82       516

# %%
## Random Forest with SMOTE-Tomek
rf = RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
n_estimators = [200,500] # number of trees in the random forest
max_features = ['auto', 'sqrt'] # number of features in consideration at every split
max_depth = [int(x) for x in np.linspace(10, 100, num = 5)] # maximum number of levels allowed in each decision tree
min_samples_split = [2, 10] # minimum sample number to split a node
min_samples_leaf = [1, 4] # minimum sample number that can be stored in a leaf node
bootstrap = [True, False] # method used to sample data points

random_grid = {'n_estimators': n_estimators,
'max_features': max_features,
'max_depth': max_depth,
'min_samples_split': min_samples_split,
'min_samples_leaf': min_samples_leaf,
'bootstrap': bootstrap}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,
               n_iter = 100, cv = 3, verbose=2, random_state=35, n_jobs = -1)

# %%
rf_random.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 156 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 101 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 55 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.9229794         nan        nan        nan 0.91652313
#  0.92313708        nan 0.91195677        nan 0.91542094 0.92691571
#         nan 0.92282187        nan        nan        nan 0.92707317
#  0.9135314         nan 0.92329431        nan 0.92093248 0.9221919
#  0.91731063        nan 0.91683811 0.91982984 0.91620844        nan
#  0.92801805 0.92628574 0.9108548         nan        nan        nan
#  0.92455388        nan 0.92297925 0.91668073 0.92628596        nan
#         nan 0.91557839 0.92219197 0.91022491        nan        nan
#  0.91620822 0.92266434        nan        nan 0.92093225 0.9193574
#         nan 0.92723055        nan 0.92345169        nan        nan
#         nan 0.91715325        nan 0.90723318 0.91825543 0.9173107
#  0.9266008         nan 0.92030228 0.91857057        nan        nan
#         nan        nan 0.92171968 0.91652342        nan 0.92171968
#         nan        nan        nan        nan        nan        nan
#         nan 0.921562   0.91164186        nan        nan        nan
#  0.91463388        nan        nan        nan 0.91636575        nan
#         nan        nan 0.92282194 0.91542101]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 32, 55, 77, 100],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 4],
#                                         'min_samples_split': [2, 10],
#                                         'n_estimators': [200, 500]},
#                    random_state=35, verbose=2)

# %%
print ('Random grid: ', random_grid, '\n')
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')
# Out:
# Random grid:  {'n_estimators': [200, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 32, 55, 77, 100], 'min_samples_split': [2, 10], 'min_samples_leaf': [1, 4], 'bootstrap': [True, False]}
#
# Best Parameters:  {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100, 'bootstrap': False}

# %%
randmf = RandomForestClassifier(n_estimators = 500, min_samples_split = 2, min_samples_leaf = 1, 
                                max_features = 'sqrt', max_depth = 100, bootstrap = False) 
randmf.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=100, n_estimators=500)

# %%
y_rf = randmf.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_rf))
# Out:
# [[ 16   0   7   1]
#  [  0 294  16   1]
#  [  2  20 135   3]
#  [  0   1   0  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        24
#            1       0.93      0.95      0.94       311
#            2       0.85      0.84      0.85       160
#            3       0.80      0.95      0.87        21
#
#     accuracy                           0.90       516
#    macro avg       0.87      0.85      0.85       516
# weighted avg       0.90      0.90      0.90       516

# %%
### AdaBoost
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
import pickle

# %%
## AdaBoost with SMOTE
ab_clf = AdaBoostClassifier()
ab_clf
# Out:
# AdaBoostClassifier()

# %%
parameters = {
    'n_estimators': [2, 4, 6, 8, 10, 12],
    'learning_rate': [(0.97 + x / 100) for x in range(0, 8)],
    'algorithm': ['SAMME', 'SAMME.R']
}
clf = GridSearchCV(ab_clf, parameters, cv=3, verbose=2, n_jobs=-1)
clf.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.97, 0.98, 0.99, 1.0, 1.01, 1.02,
#                                            1.03, 1.04],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.03, n_estimators=12)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1.03, 'n_estimators': 12}

# %%
randab = AdaBoostClassifier(n_estimators = 12, learning_rate = 1.03, algorithm = 'SAMME')
randab.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.03, n_estimators=12)

# %%
y_ab = randab.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_ab))
# Out:
# [[ 21   0   3   0]
#  [  1 128 182   0]
#  [ 46  22  91   1]
#  [  6   6   1   8]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_ab))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.88      0.43        24
#            1       0.82      0.41      0.55       311
#            2       0.33      0.57      0.42       160
#            3       0.89      0.38      0.53        21
#
#     accuracy                           0.48       516
#    macro avg       0.58      0.56      0.48       516
# weighted avg       0.65      0.48      0.50       516

# %%
## AdaBoost with ADASYN
ab_clf = AdaBoostClassifier()
ab_clf
# Out:
# AdaBoostClassifier()

# %%
parameters = {
    'n_estimators': [2, 4, 6, 8, 10, 12],
    'learning_rate': [(0.97 + x / 100) for x in range(0, 8)],
    'algorithm': ['SAMME', 'SAMME.R']
}
clf = GridSearchCV(ab_clf, parameters, cv=3, verbose=2, n_jobs=-1)
clf.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.97, 0.98, 0.99, 1.0, 1.01, 1.02,
#                                            1.03, 1.04],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME', n_estimators=12)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1.0, 'n_estimators': 12}

# %%
randab = AdaBoostClassifier(n_estimators = 12, learning_rate = 1.0, algorithm = 'SAMME')
randab.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# AdaBoostClassifier(algorithm='SAMME', n_estimators=12)

# %%
y_ab = randab.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_ab))
# Out:
# [[ 20   1   2   1]
#  [  8  69 234   0]
#  [ 25  22 104   9]
#  [  4   4   1  12]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_ab))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.83      0.49        24
#            1       0.72      0.22      0.34       311
#            2       0.30      0.65      0.42       160
#            3       0.55      0.57      0.56        21
#
#     accuracy                           0.40       516
#    macro avg       0.48      0.57      0.45       516
# weighted avg       0.57      0.40      0.38       516

# %%
## AdaBoost with SMOTE-ENN
ab_clf = AdaBoostClassifier()
ab_clf
# Out:
# AdaBoostClassifier()

# %%
parameters = {
    'n_estimators': [2, 4, 6, 8, 10, 12],
    'learning_rate': [(0.97 + x / 100) for x in range(0, 8)],
    'algorithm': ['SAMME', 'SAMME.R']
}
clf = GridSearchCV(ab_clf, parameters, cv=3, verbose=2, n_jobs=-1)
clf.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.97, 0.98, 0.99, 1.0, 1.01, 1.02,
#                                            1.03, 1.04],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.04, n_estimators=12)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1.04, 'n_estimators': 12}

# %%
randab = AdaBoostClassifier(n_estimators = 12, learning_rate = 1.04, algorithm = 'SAMME')
randab.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.04, n_estimators=12)

# %%
y_ab = randab.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_ab))
# Out:
# [[ 17   0   6   1]
#  [  0  11 296   4]
#  [ 12   3 137   8]
#  [  1   4   4  12]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_ab))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.71      0.63        24
#            1       0.61      0.04      0.07       311
#            2       0.31      0.86      0.45       160
#            3       0.48      0.57      0.52        21
#
#     accuracy                           0.34       516
#    macro avg       0.49      0.54      0.42       516
# weighted avg       0.51      0.34      0.23       516

# %%
## AdaBoost with SMOTE-Tomek
ab_clf = AdaBoostClassifier()
ab_clf
# Out:
# AdaBoostClassifier()

# %%
parameters = {
    'n_estimators': [2, 4, 6, 8, 10, 12],
    'learning_rate': [(0.97 + x / 100) for x in range(0, 8)],
    'algorithm': ['SAMME', 'SAMME.R']
}
clf = GridSearchCV(ab_clf, parameters, cv=3, verbose=2, n_jobs=-1)
clf.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.97, 0.98, 0.99, 1.0, 1.01, 1.02,
#                                            1.03, 1.04],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]},
#              verbose=2)

# %%
with open('clf.pickle', 'wb') as fp:
    pickle.dump(clf, fp)

# %%
clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.01, n_estimators=12)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1.01, 'n_estimators': 12}

# %%
randab = AdaBoostClassifier(n_estimators = 12, learning_rate = 1.01, algorithm = 'SAMME')
randab.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1.01, n_estimators=12)

# %%
y_ab = randab.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_ab))
# Out:
# [[ 17   2   5   0]
#  [  0 243  67   1]
#  [ 30  37  91   2]
#  [  4   7   0  10]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_ab))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.71      0.45        24
#            1       0.84      0.78      0.81       311
#            2       0.56      0.57      0.56       160
#            3       0.77      0.48      0.59        21
#
#     accuracy                           0.70       516
#    macro avg       0.63      0.63      0.60       516
# weighted avg       0.73      0.70      0.71       516

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/32/10/4689bda37403f7dd029d550c4446e0097c2f33b8ae877b235e76d5c49bc2/xgboost-2.0.0-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.0-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\hi\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\hi\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.0-py3-none-win_amd64.whl (99.7 MB)
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.2/99.7 MB 7.6 MB/s eta 0:00:14
#    ---------------------------------------- 0.6/99.7 MB 8.1 MB/s eta 0:00:13
#    ---------------------------------------- 1.1/99.7 MB 8.5 MB/s eta 0:00:12
#     --------------------------------------- 1.5/99.7 MB 8.9 MB/s eta 0:00:12
#     --------------------------------------- 2.0/99.7 MB 9.0 MB/s eta 0:00:11
#     --------------------------------------- 2.4/99.7 MB 9.1 MB/s eta 0:00:11
#    - -------------------------------------- 2.9/99.7 MB 9.2 MB/s eta 0:00:11
#    - -------------------------------------- 3.3/99.7 MB 9.3 MB/s eta 0:00:11
#    - -------------------------------------- 3.8/99.7 MB 9.3 MB/s eta 0:00:11
#    - -------------------------------------- 4.3/99.7 MB 9.4 MB/s eta 0:00:11
#    - -------------------------------------- 4.7/99.7 MB 9.4 MB/s eta 0:00:11
#    -- ------------------------------------- 5.2/99.7 MB 9.4 MB/s eta 0:00:11
#    -- ------------------------------------- 5.6/99.7 MB 9.4 MB/s eta 0:00:10
#    -- ------------------------------------- 6.1/99.7 MB 9.5 MB/s eta 0:00:10
#    -- ------------------------------------- 6.4/99.7 MB 9.3 MB/s eta 0:00:11
#    -- ------------------------------------- 7.0/99.7 MB 9.5 MB/s eta 0:00:10
#    -- ------------------------------------- 7.4/99.7 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 7.9/99.7 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 8.3/99.7 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 8.8/99.7 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 9.3/99.7 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 9.7/99.7 MB 9.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 10.1/99.7 MB 9.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 10.6/99.7 MB 9.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 11.1/99.7 MB 9.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 11.5/99.7 MB 9.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 12.0/99.7 MB 9.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 12.4/99.7 MB 9.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 12.9/99.7 MB 9.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 13.3/99.7 MB 9.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 13.8/99.7 MB 9.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 14.2/99.7 MB 9.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 14.7/99.7 MB 9.8 MB/s eta 0:00:09
#    ------ --------------------------------- 15.2/99.7 MB 9.8 MB/s eta 0:00:09
#    ------ --------------------------------- 15.6/99.7 MB 9.8 MB/s eta 0:00:09
#    ------ --------------------------------- 16.1/99.7 MB 9.8 MB/s eta 0:00:09
#    ------ --------------------------------- 16.5/99.7 MB 9.9 MB/s eta 0:00:09
#    ------ --------------------------------- 17.0/99.7 MB 9.8 MB/s eta 0:00:09
#    ------ --------------------------------- 17.4/99.7 MB 9.8 MB/s eta 0:00:09
#    ------- -------------------------------- 17.9/99.7 MB 9.8 MB/s eta 0:00:09
#    ------- -------------------------------- 18.3/99.7 MB 9.8 MB/s eta 0:00:09
#    ------- -------------------------------- 18.7/99.7 MB 9.6 MB/s eta 0:00:09
#    ------- -------------------------------- 19.2/99.7 MB 9.8 MB/s eta 0:00:09
#    ------- -------------------------------- 19.7/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 20.1/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 20.6/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 21.0/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 21.5/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 21.9/99.7 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 22.4/99.7 MB 9.6 MB/s eta 0:00:09
#    --------- ------------------------------ 22.8/99.7 MB 9.6 MB/s eta 0:00:08
#    --------- ------------------------------ 23.3/99.7 MB 9.6 MB/s eta 0:00:08
#    --------- ------------------------------ 23.7/99.7 MB 9.6 MB/s eta 0:00:08
#    --------- ------------------------------ 24.2/99.7 MB 9.6 MB/s eta 0:00:08
#    --------- ------------------------------ 24.6/99.7 MB 9.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.1/99.7 MB 9.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.5/99.7 MB 9.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.0/99.7 MB 9.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.5/99.7 MB 9.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.9/99.7 MB 9.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 27.4/99.7 MB 9.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 27.8/99.7 MB 9.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 28.3/99.7 MB 9.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 28.7/99.7 MB 9.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 29.2/99.7 MB 9.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 29.6/99.7 MB 9.6 MB/s eta 0:00:08
#    ------------ --------------------------- 30.1/99.7 MB 9.8 MB/s eta 0:00:08
#    ------------ --------------------------- 30.4/99.7 MB 9.8 MB/s eta 0:00:08
#    ------------ --------------------------- 31.0/99.7 MB 9.8 MB/s eta 0:00:08
#    ------------ --------------------------- 31.3/99.7 MB 9.6 MB/s eta 0:00:08
#    ------------ --------------------------- 31.9/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------ --------------------------- 32.3/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 32.8/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 33.2/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 33.7/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 34.1/99.7 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 34.6/99.7 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 35.0/99.7 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 35.5/99.7 MB 9.6 MB/s eta 0:00:07
#    -------------- ------------------------- 35.9/99.7 MB 9.6 MB/s eta 0:00:07
#    -------------- ------------------------- 36.4/99.7 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 36.8/99.7 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 37.3/99.7 MB 9.8 MB/s eta 0:00:07
#    --------------- ------------------------ 37.7/99.7 MB 9.8 MB/s eta 0:00:07
#    --------------- ------------------------ 38.0/99.7 MB 9.5 MB/s eta 0:00:07
#    --------------- ------------------------ 38.6/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.6/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.6/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.9/99.7 MB 8.7 MB/s eta 0:00:07
#    --------------- ------------------------ 39.3/99.7 MB 8.7 MB/s eta 0:00:07
#    --------------- ------------------------ 39.8/99.7 MB 8.7 MB/s eta 0:00:07
#    --------------- ------------------------ 39.8/99.7 MB 8.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 40.2/99.7 MB 8.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 40.7/99.7 MB 8.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 41.1/99.7 MB 8.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 41.6/99.7 MB 8.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 42.0/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 42.5/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 42.9/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 43.4/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 43.8/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 44.3/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 44.7/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 45.2/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 45.6/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 46.1/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 46.6/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 47.0/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------- -------------------- 47.5/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------- -------------------- 47.9/99.7 MB 8.5 MB/s eta 0:00:07
#    ------------------- -------------------- 48.4/99.7 MB 8.5 MB/s eta 0:00:07
#    ------------------- -------------------- 48.8/99.7 MB 8.5 MB/s eta 0:00:06
#    ------------------- -------------------- 49.3/99.7 MB 9.4 MB/s eta 0:00:06
#    ------------------- -------------------- 49.7/99.7 MB 9.4 MB/s eta 0:00:06
#    -------------------- ------------------- 50.2/99.7 MB 9.8 MB/s eta 0:00:06
#    -------------------- ------------------- 50.6/99.7 MB 9.8 MB/s eta 0:00:06
#    -------------------- ------------------- 51.1/99.7 MB 9.8 MB/s eta 0:00:05
#    -------------------- ------------------- 51.5/99.7 MB 9.8 MB/s eta 0:00:05
#    -------------------- ------------------- 52.0/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 52.4/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 52.9/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 53.4/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 53.8/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 54.3/99.7 MB 9.8 MB/s eta 0:00:05
#    --------------------- ------------------ 54.7/99.7 MB 9.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.2/99.7 MB 9.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.6/99.7 MB 9.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 56.1/99.7 MB 9.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 56.5/99.7 MB 9.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 57.0/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 57.5/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 57.9/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 58.3/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 58.8/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 59.2/99.7 MB 9.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 59.7/99.7 MB 9.8 MB/s eta 0:00:05
#    ------------------------ --------------- 60.1/99.7 MB 9.8 MB/s eta 0:00:05
#    ------------------------ --------------- 60.6/99.7 MB 9.8 MB/s eta 0:00:05
#    ------------------------ --------------- 61.1/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------ --------------- 61.5/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------ --------------- 62.0/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 62.4/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 62.9/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 63.3/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 63.8/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 64.3/99.7 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 64.7/99.7 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 65.0/99.7 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 65.6/99.7 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 66.1/99.7 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 66.5/99.7 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 67.0/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 67.4/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 67.9/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 68.4/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 68.8/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 69.3/99.7 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 69.7/99.7 MB 9.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 70.1/99.7 MB 9.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 70.6/99.7 MB 9.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 71.0/99.7 MB 9.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.5/99.7 MB 9.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 72.0/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 72.4/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 72.9/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.3/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.8/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.2/99.7 MB 9.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.7/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------ --------- 75.1/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------ --------- 75.3/99.7 MB 9.9 MB/s eta 0:00:03
#    ------------------------------ --------- 76.0/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------ --------- 76.5/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------ --------- 76.9/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------- -------- 77.4/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------- -------- 77.9/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------- -------- 78.0/99.7 MB 9.6 MB/s eta 0:00:03
#    ------------------------------- -------- 78.7/99.7 MB 9.8 MB/s eta 0:00:03
#    ------------------------------- -------- 79.2/99.7 MB 9.8 MB/s eta 0:00:03
#    ------------------------------- -------- 79.6/99.7 MB 9.8 MB/s eta 0:00:03
#    -------------------------------- ------- 80.1/99.7 MB 9.6 MB/s eta 0:00:03
#    -------------------------------- ------- 80.6/99.7 MB 9.8 MB/s eta 0:00:02
#    -------------------------------- ------- 81.0/99.7 MB 9.6 MB/s eta 0:00:02
#    -------------------------------- ------- 81.5/99.7 MB 9.6 MB/s eta 0:00:02
#    -------------------------------- ------- 82.0/99.7 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 82.4/99.7 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 82.9/99.7 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 83.3/99.7 MB 9.8 MB/s eta 0:00:02
#    --------------------------------- ------ 83.8/99.7 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 84.2/99.7 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 84.7/99.7 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.1/99.7 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.6/99.7 MB 10.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.0/99.7 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.5/99.7 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.7/99.7 MB 9.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.4/99.7 MB 9.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.8/99.7 MB 9.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.3/99.7 MB 10.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.8/99.7 MB 9.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.2/99.7 MB 9.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.7/99.7 MB 9.8 MB/s eta 0:00:02
#    ------------------------------------ --- 90.1/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 90.5/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 91.0/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 91.5/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 91.9/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 92.4/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 92.8/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 93.3/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 93.8/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 94.1/99.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 94.6/99.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 95.1/99.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 95.5/99.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.0/99.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.5/99.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.9/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  97.4/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  97.8/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  98.3/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  98.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.2/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.6/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 99.7/99.7 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.0

# %%
### Extreme Gradient Boosting (XGBoost)
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
import pickle

# %%
## XGBoost with SMOTE
model = XGBClassifier()
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
params = {
    'n_estimators': [200, 500],
    'learning_rate': [0.01,0.05],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0.5, 1],
    'reg_alpha': [0.5, 1],
    'reg_lambda': [0.5, 5],
    'base_score': [0.2, 1]
}

gs_XGB = GridSearchCV(model, params, cv = 3, verbose = 2, n_jobs = -1)
gs_XGB.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 3 folds for each of 128 candidates, totalling 384 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'base_score': [0.2, 1],
#                          'booster': ['gbtree', 'gblinear'], 'gamma': [0.5, 1],
#                          'learning_rate': [0.01, 0.05],
#                          'n_estimators': [200, 500], 'reg_alpha': [0.5, 1],
#                          'reg_lambda': [0.5, 5]},
#              verbose=2)

# %%
print('Best score:', gs_XGB.best_score_)
print('Best params:', gs_XGB.best_params_)
# Out:
# Best score: 0.9205436292442458
# Best params: {'base_score': 0.2, 'booster': 'gbtree', 'gamma': 0.5, 'learning_rate': 0.05, 'n_estimators': 500, 'reg_alpha': 0.5, 'reg_lambda': 5}

# %%
with open('gs_XGB.pickle', 'wb') as fp:
    pickle.dump(gs_XGB, fp)

# %%
gs_XGB.best_estimator_
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
gs_XGB.best_params_
# Out:
# {'base_score': 0.2,
#  'booster': 'gbtree',
#  'gamma': 0.5,
#  'learning_rate': 0.05,
#  'n_estimators': 500,
#  'reg_alpha': 0.5,
#  'reg_lambda': 5}

# %%
randxgb = XGBClassifier(base_score = 0.2, booster = 'gbtree', gamma = 0.5,
                       learning_rate = 0.05, n_estimators = 500, reg_alpha = 0.5, reg_lambda = 5)
randxgb.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_XGB = randxgb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_XGB))
# Out:
# [[ 18   0   3   3]
#  [  0 288  23   0]
#  [  5  13 141   1]
#  [  0   1   0  20]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_XGB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.77        24
#            1       0.95      0.93      0.94       311
#            2       0.84      0.88      0.86       160
#            3       0.83      0.95      0.89        21
#
#     accuracy                           0.91       516
#    macro avg       0.85      0.88      0.86       516
# weighted avg       0.91      0.91      0.91       516

# %%
## XGBoost with ADASYN
model = XGBClassifier()
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
params = {
    'n_estimators': [200, 500],
    'learning_rate': [0.01,0.05],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0.5, 1],
    'reg_alpha': [0.5, 1],
    'reg_lambda': [0.5, 5],
    'base_score': [0.2, 1]
}

gs_XGB = GridSearchCV(model, params, cv = 3, verbose = 2, n_jobs = -1)
gs_XGB.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 3 folds for each of 128 candidates, totalling 384 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'base_score': [0.2, 1],
#                          'booster': ['gbtree', 'gblinear'], 'gamma': [0.5, 1],
#                          'learning_rate': [0.01, 0.05],
#                          'n_estimators': [200, 500], 'reg_alpha': [0.5, 1],
#                          'reg_lambda': [0.5, 5]},
#              verbose=2)

# %%
print('Best score:', gs_XGB.best_score_)
print('Best params:', gs_XGB.best_params_)
# Out:
# Best score: 0.9089219330855017
# Best params: {'base_score': 0.2, 'booster': 'gbtree', 'gamma': 0.5, 'learning_rate': 0.05, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 0.5}

# %%
with open('gs_XGB.pickle', 'wb') as fp:
    pickle.dump(gs_XGB, fp)

# %%
gs_XGB.best_estimator_
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
gs_XGB.best_params_
# Out:
# {'base_score': 0.2,
#  'booster': 'gbtree',
#  'gamma': 0.5,
#  'learning_rate': 0.05,
#  'n_estimators': 500,
#  'reg_alpha': 1,
#  'reg_lambda': 0.5}

# %%
randxgb = XGBClassifier(base_score = 0.2, booster = 'gbtree', gamma = 0.5,
                       learning_rate = 0.05, n_estimators = 500, reg_alpha = 1, reg_lambda = 0.5)
randxgb.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_XGB = randxgb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_XGB))
# Out:
# [[ 19   0   2   3]
#  [  0 291  20   0]
#  [  4  12 142   2]
#  [  0   0   0  21]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_XGB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        24
#            1       0.96      0.94      0.95       311
#            2       0.87      0.89      0.88       160
#            3       0.81      1.00      0.89        21
#
#     accuracy                           0.92       516
#    macro avg       0.87      0.90      0.88       516
# weighted avg       0.92      0.92      0.92       516

# %%
## XGBoost with SMOTE-ENN
model = XGBClassifier()
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
params = {
    'n_estimators': [200, 500],
    'learning_rate': [0.01,0.05],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0.5, 1],
    'reg_alpha': [0.5, 1],
    'reg_lambda': [0.5, 5],
    'base_score': [0.2, 1]
}

gs_XGB = GridSearchCV(model, params, cv = 3, verbose = 2, n_jobs = -1)
gs_XGB.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 3 folds for each of 128 candidates, totalling 384 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'base_score': [0.2, 1],
#                          'booster': ['gbtree', 'gblinear'], 'gamma': [0.5, 1],
#                          'learning_rate': [0.01, 0.05],
#                          'n_estimators': [200, 500], 'reg_alpha': [0.5, 1],
#                          'reg_lambda': [0.5, 5]},
#              verbose=2)

# %%
print('Best score:', gs_XGB.best_score_)
print('Best params:', gs_XGB.best_params_)
# Out:
# Best score: 0.9595098992507128
# Best params: {'base_score': 0.2, 'booster': 'gbtree', 'gamma': 0.5, 'learning_rate': 0.05, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.5}

# %%
with open('gs_XGB.pickle', 'wb') as fp:
    pickle.dump(gs_XGB, fp)

# %%
gs_XGB.best_estimator_
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
gs_XGB.best_params_
# Out:
# {'base_score': 0.2,
#  'booster': 'gbtree',
#  'gamma': 0.5,
#  'learning_rate': 0.05,
#  'n_estimators': 200,
#  'reg_alpha': 1,
#  'reg_lambda': 0.5}

# %%
randxgb = XGBClassifier(base_score = 0.2, booster = 'gbtree', gamma = 0.5,
                       learning_rate = 0.05, n_estimators = 200, reg_alpha = 1, reg_lambda = 0.5)
randxgb.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_XGB = randxgb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_XGB))
# Out:
# [[ 17   0   4   3]
#  [  0 270  39   2]
#  [  5  13 137   5]
#  [  0   0   0  21]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_XGB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74        24
#            1       0.95      0.87      0.91       311
#            2       0.76      0.86      0.81       160
#            3       0.68      1.00      0.81        21
#
#     accuracy                           0.86       516
#    macro avg       0.79      0.86      0.82       516
# weighted avg       0.87      0.86      0.87       516

# %%
## XGBoost with SMOTE-Tomek
model = XGBClassifier()
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
params = {
    'n_estimators': [200, 500],
    'learning_rate': [0.01,0.05],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0.5, 1],
    'reg_alpha': [0.5, 1],
    'reg_lambda': [0.5, 5],
    'base_score': [0.2, 1]
}

gs_XGB = GridSearchCV(model, params, cv = 3, verbose = 2, n_jobs = -1)
gs_XGB.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# Fitting 3 folds for each of 128 candidates, totalling 384 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'base_score': [0.2, 1],
#                          'booster': ['gbtree', 'gblinear'], 'gamma': [0.5, 1],
#                          'learning_rate': [0.01, 0.05],
#                          'n_estimators': [200, 500], 'reg_alpha': [0.5, 1],
#                          'reg_lambda': [0.5, 5]},
#              verbose=2)

# %%
print('Best score:', gs_XGB.best_score_)
print('Best params:', gs_XGB.best_params_)
# Out:
# Best score: 0.9226646355202387
# Best params: {'base_score': 0.2, 'booster': 'gbtree', 'gamma': 0.5, 'learning_rate': 0.05, 'n_estimators': 500, 'reg_alpha': 0.5, 'reg_lambda': 0.5}

# %%
with open('gs_XGB.pickle', 'wb') as fp:
    pickle.dump(gs_XGB, fp)

# %%
gs_XGB.best_estimator_
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
gs_XGB.best_params_
# Out:
# {'base_score': 0.2,
#  'booster': 'gbtree',
#  'gamma': 0.5,
#  'learning_rate': 0.05,
#  'n_estimators': 500,
#  'reg_alpha': 0.5,
#  'reg_lambda': 0.5}

# %%
randxgb = XGBClassifier(base_score = 0.2, booster = 'gbtree', gamma = 0.5,
                       learning_rate = 0.05, n_estimators = 500, reg_alpha = 0.5, reg_lambda = 0.5)
randxgb.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))
# Out:
# XGBClassifier(base_score=0.2, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_XGB = randxgb.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_XGB))
# Out:
# [[ 17   0   4   3]
#  [  0 288  22   1]
#  [  4  14 141   1]
#  [  0   1   0  20]]

# %%
print(classification_report(sediment_encoded_test_y, y_XGB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.76        24
#            1       0.95      0.93      0.94       311
#            2       0.84      0.88      0.86       160
#            3       0.80      0.95      0.87        21
#
#     accuracy                           0.90       516
#    macro avg       0.85      0.87      0.86       516
# weighted avg       0.90      0.90      0.90       516

# %%
### Support Vector Machine (SVM)
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
## SVM with SMOTE
svm = SVC()
svm
# Out:
# SVC()

# %%
param_grid = {'C': [0.1, 10],
              'gamma': ['scale','auto'],
              'kernel': ['rbf','linear']}
grid = GridSearchCV(svm, param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Fitting the model
grid.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=2)

# %%
print(grid.best_params_)
print(grid.best_estimator_.get_params())
# Out:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# {'C': 0.1, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
randsvm = SVC(C = 0.1, gamma = 'scale', kernel = 'linear')
randsvm.fit(np.array(sediment_train_x_sm), np.array(sediment_encoded_train_y_sm))
# Out:
# SVC(C=0.1, kernel='linear')

# %%
y_SVM = randsvm.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_SVM))
# Out:
# [[ 20   0   3   1]
#  [  0 247  63   1]
#  [  8  38 112   2]
#  [  2   4   0  15]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.83      0.74        24
#            1       0.85      0.79      0.82       311
#            2       0.63      0.70      0.66       160
#            3       0.79      0.71      0.75        21
#
#     accuracy                           0.76       516
#    macro avg       0.74      0.76      0.74       516
# weighted avg       0.77      0.76      0.77       516

# %%
## SVM with ADASYN
svm = SVC()
svm
# Out:
# SVC()

# %%
param_grid = {'C': [0.1, 10],
              'gamma': ['scale','auto'],
              'kernel': ['rbf','linear']}
grid = GridSearchCV(svm, param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Fitting the model
grid.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=2)

# %%
print(grid.best_params_)
print(grid.best_estimator_.get_params())
# Out:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# {'C': 0.1, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
randsvm = SVC(C = 0.1, gamma = 'scale', kernel = 'linear')
randsvm.fit(np.array(sediment_train_x_ads), np.array(sediment_encoded_train_y_ads))
# Out:
# SVC(C=0.1, kernel='linear')

# %%
y_SVM = randsvm.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_SVM))
# Out:
# [[ 21   0   3   0]
#  [  0 244  67   0]
#  [  9  36 113   2]
#  [  1   2   1  17]]

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.88      0.76        24
#            1       0.87      0.78      0.82       311
#            2       0.61      0.71      0.66       160
#            3       0.89      0.81      0.85        21
#
#     accuracy                           0.77       516
#    macro avg       0.76      0.79      0.77       516
# weighted avg       0.78      0.77      0.77       516

# %%
## SVM with SMOTE-ENN
svm = SVC()
svm
# Out:
# SVC()

# %%
param_grid = {'C': [0.1, 10],
              'gamma': ['scale','auto'],
              'kernel': ['rbf','linear']}
grid = GridSearchCV(svm, param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Fitting the model
grid.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits

# %%
print(grid.best_params_)
print(grid.best_estimator_.get_params())

# %%
randsvm = SVC(C = 0.1, gamma = 0.01, kernel = 'rbf')
randsvm.fit(np.array(sediment_train_x_sme), np.array(sediment_encoded_train_y_sme))

# %%
y_SVM = randsvm.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_SVM))

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_SVM))

# %%
## SVM with SMOTE-Tomek
svm = SVC()
svm

# %%
param_grid = {'C': [0.1, 10],
              'gamma': ['scale','auto'],
              'kernel': ['rbf','linear']}
grid = GridSearchCV(svm, param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Fitting the model
grid.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))

# %%
print(grid.best_params_)
print(grid.best_estimator_.get_params())

# %%
randsvm = SVC(C = 0.1, gamma = 0.01, kernel = 'rbf')
randsvm.fit(np.array(sediment_train_x_smt), np.array(sediment_encoded_train_y_smt))

# %%
y_SVM = randsvm.predict(np.array(sediment_test_x))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(sediment_encoded_test_y, y_SVM))

# %%
from sklearn.metrics import classification_report
print(classification_report(sediment_encoded_test_y, y_SVM))
